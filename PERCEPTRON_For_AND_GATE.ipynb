# %% [markdown]
# <a href="https://colab.research.google.com/github/pranjalbhawsar11/machine-learning/blob/master/PERCEPTRON_For_AND_GATE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Perceptron Learning Algorithm Code

# %%
import numpy as np

# %%
W = np.zeros(2+1)
print(W)
print(W.shape)
# Out:
# [0. 0. 0.]
# (3,)

# %%
X=[2,3]
np.insert(X, 0, 1)
# Out:
# array([1, 2, 3])

# %%
# initialization code
def __init__(self, input_size, lr=1, epochs=10, bias=1):
    self.W = np.zeros(input_size+bias)
    self.epochs = epochs
    self.lr = lr

# %%
# Activation function code which is a simple step function
def activation_fn(self, x):
        #return (x >= 0).astype(np.float32)
        return 1 if x >= 0 else 0

# %%
# Calculating dot product of W and X (input vector) and applying step function
def predict(self, x):
        z = self.W.T.dot(x)
        print(z)
        a = self.activation_fn(z)
        return a

# %%
# Perceptron Learning code running all the samples for given epochs or iterations
def fit(self, X, OutputLabel):
    no_of_smaples=4
    for _ in range(self.epochs):
        for i in range(no_of_samples):
            y = self.predict(X[i])
            e = OutputLabel[i] - y
            self.W = self.W + self.lr * e * np.insert(X[i], 0, 1)

# %% [markdown]
# # The complete executable code of Perceptron model

# %%
 
class Perceptron(object):
    """Implements a perceptron network"""
    def __init__(self, input_size, lr=1, epochs=100):
        self.W = np.zeros(input_size+1)
        # add one for bias
        self.epochs = epochs
        self.lr = lr
    
    def activation_fn(self, x):
        #return (x >= 0).astype(np.float32)
        return 1 if x >= 0 else 0
 
    def predict(self, x):
        z = self.W.T.dot(x)
        print('z')
        print(z)
        a = self.activation_fn(z)
        return a
 
    def fit(self, X, d):
        for _ in range(self.epochs):
            for i in range(d.shape[0]):
                x = np.insert(X[i], 0, 1)
                
                y = self.predict(x)
                e = d[i] - y
                self.W = self.W + self.lr * e * x

# %% [markdown]
# # AND GATE EXAMPLE WITH NO OF SAMPLES/RECORDS AS 4 AND EPOCHS AS 100

# %%
if __name__ == '__main__':
    X = np.array([
        [0, 0],
        [0, 1],
        [1, 0],
        [1, 1]
    ])
    d = np.array([0, 0, 0, 1])
 
    perceptron = Perceptron(input_size=2)
    perceptron.fit(X, d)
    print(perceptron.W)
# Out:
# z
# 0.0
# z
# -1.0
# z
# -1.0
# z
# -1.0
# z
# 0.0
# z
# 0.0
# z
# -1.0
# z
# -1.0
# z
# -1.0
# z
# 0.0
# z
# 0.0
# z
# -2.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -1.0
# z
# -2.0
# z
# 0.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# z
# -2.0
# z
# -1.0
# z
# 0.0
# z
# -3.0
# ...

# %% [markdown]
# # Using the AND gate data, we should get a weight vector of [-3, 2, 1]. This means that the bias is -3 and the weights are 2 and 1 for x_1 and x_2, respectively.

# %% [markdown]
# # LETS TEST MANUALLY
# # let us test for x=[0, 1]

# %%
x=[1, 0, 1]
y= -3*1+2*0+1*1
y
# Out:
# -2

# %% [markdown]
# # since it is a negative value on applying activation function we get zero which is correct
